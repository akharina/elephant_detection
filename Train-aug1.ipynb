# %% [markdown]
# # Training with image augmentation

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# show images inline
# %matplotlib inline

#activate tensorboard
# %load_ext tensorboard

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
from tensorflow import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time

# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

# use this to change which GPU to use
gpu = 0

# set the modified tf session as backend in keras
setup_gpu(gpu)
# Out:
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.5/site-packages/keras_retinanet/utils/gpu.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.5/site-packages/keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.5/site-packages/keras_retinanet/utils/gpu.py:53: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Modifying train.py file
#
# In this training step, we only wanted to apply visual effect augmentation. To do this, we modified keras-retinanet/keras_retinanet/bin/train.py file and disabled (commented out) all the relevant ```transform_generator``` calls (lines 226-237, 285).

# %% [markdown]
# ## Train using pre-existing snapshot

# %%
# !python3 ../keras-retinanet/keras_retinanet/bin/train.py --compute-val-loss --batch-size 16  --steps 100 --epochs 10 --gpu 0 --backbone resnet50  --config config/config.ini --snapshot ../snapshots/Nov27_1_lr103_aug/cont/resnet50_csv_02.h5  --lr 1e-3 --snapshot-path ../snapshots/Nov27_1_lr103_aug/cont2  --freeze-backbone  --tensorboard-dir ../summaries/Nov27_lr103_aug --random-transform csv annotations.csv classes.csv --val-annotations val_annot.csv
# Out:
# Using TensorFlow backend.
# 2019-11-28 02:11:54.659763: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-28 02:11:56.586254: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...

# %%
# !python3 ../keras-retinanet/keras_retinanet/bin/train.py --compute-val-loss --batch-size 16  --steps 100 --epochs 16 --gpu 0 --backbone resnet50  --config config/config.ini --snapshot ../snapshots/Nov27_1_lr103_aug/cont2/resnet50_csv_10.h5  --lr 1e-3 --snapshot-path ../snapshots/Nov27_1_lr103_aug/cont3  --freeze-backbone  --tensorboard-dir ../summaries/Nov27_lr103_aug --random-transform csv annotations.csv classes.csv --val-annotations val_annot.csv
# Out:
# Using TensorFlow backend.
# 2019-11-28 17:09:59.031619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:51: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2019-11-28 17:10:03.812297: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# ...
