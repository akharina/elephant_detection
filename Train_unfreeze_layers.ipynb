# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# show images inline
# %matplotlib inline

#activate tensorboard
# %load_ext tensorboard

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2

# import keras
from tensorflow import keras

# import keras_retinanet
from keras_retinanet import models
from keras_retinanet.utils.image import read_image_bgr, preprocess_image, resize_image
from keras_retinanet.utils.visualization import draw_box, draw_caption
from keras_retinanet.utils.colors import label_color
from keras_retinanet.utils.gpu import setup_gpu

# import miscellaneous modules
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import time

# set tf backend to allow memory to grow, instead of claiming everything
import tensorflow as tf

# use this to change which GPU to use
gpu = 0

# set the modified tf session as backend in keras
setup_gpu(gpu)
# Out:
# WARNING:tensorflow:From /home/jupyter/.local/lib/python3.5/site-packages/keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
    raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !python3 ../keras-retinanet/keras_retinanet/bin/train.py  --compute-val-loss --batch-size 16  --steps 100 --epochs 60 --gpu 0 --weights ../keras-retinanet/snapshots/resnet50_coco_best_v2.1.0.h5 --backbone resnet50  --config config/config.ini --snapshot-path ../snapshots/Nov28_1_lr103_unf22 --freeze-backbone --tensorboard-dir ../summaries/Nov28_lr103 csv annotations.csv classes.csv --val-annotations val_annot.csv
# Out:
# Using TensorFlow backend.
# 2019-11-28 17:30:11.344105: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# 2019-11-28 17:30:13.344146: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-28 17:30:13.352472: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-28 17:30:13.353474: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55bf49e5eb10 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !python3 ../keras-retinanet/keras_retinanet/bin/train.py  --compute-val-loss --batch-size 16  --steps 100 --epochs 80 --gpu 0 --snapshot ../snapshots/Nov27_1_lr103/cont/resnet50_csv_17.h5 --backbone resnet50  --config config/config.ini --snapshot-path ../snapshots/Nov27_1_lr103/cont2 --freeze-backbone --tensorboard-dir ../summaries/Nov27_lr103 csv annotations.csv classes.csv --val-annotations val_annot.csv
# Out:
# Using TensorFlow backend.
# 2019-11-28 02:25:41.726068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# WARNING:tensorflow:From ../keras-retinanet/keras_retinanet/bin/../../keras_retinanet/utils/gpu.py:53: The name tf.keras.backend.set_session is deprecated. Please use tf.compat.v1.keras.backend.set_session instead.
#
# 2019-11-28 02:25:43.658770: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-28 02:25:43.666282: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-28 02:25:43.667257: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556240e35c50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...
